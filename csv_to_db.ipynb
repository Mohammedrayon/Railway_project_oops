# %%
import pandas as pd
import numpy as np

df = pd.read_csv('train_info.csv')
df
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('database/train.db')
c = conn.cursor()

# Create the table
c.execute('''
CREATE TABLE IF NOT EXISTS train_info (
    Train_No INTEGER PRIMARY KEY,
    Train_Name TEXT,
    Source_Station TEXT,
    Destination_Station TEXT
)
''')
conn.commit()

# Select only the required columns from the DataFrame
df = df[['Train_No', 'Train_Name', 'Source_Station_Name', 'Destination_Station_Name']]

# Rename the columns to match the database schema
df.columns = ['Train_No', 'Train_Name', 'Source_Station', 'Destination_Station']

# Store the DataFrame in the SQLite database
df.to_sql('train_info', conn, if_exists='replace', index=False)

# Query to select all data from the table
c.execute('SELECT * FROM train_info')

# Fetch and print all rows
for row in c.fetchall():
    print(row)

conn.close()
# Out:
# (107, 'SWV-MAO-VLNK', 'SAWANTWADI ROAD', 'MADGOAN JN.')
# (108, 'VLNK-MAO-SWV', 'MADGOAN JN.', 'SAWANTWADI ROAD')
# (128, 'MAO-KOP SPEC', 'MADGOAN JN.', 'CHHATRAPATI SHAHU MAHARAJ TERMINUS')
# (290, 'PALACE ON WH', 'DELHI-SAFDAR JANG', 'DELHI-SAFDAR JANG')
# (401, 'BSB BHARATDA', 'AURANGABAD', 'VARANASI JN.')
# (421, 'LKO-SVDK FTR', 'LUCKNOW JN.', 'SHRI MATA VAISHNO DEVI KATRA')
# (422, 'SVDK-LKO FTR', 'SHRI MATA VAISHNO DEVI KATRA', 'LUCKNOW JN.')
# (477, 'FTR TRAIN NO', 'SIRSA', 'SIRSA')
# (502, 'RJPB-UMB FTR', 'RAJENDRANAGAR TERMINAL', 'AMBALA CANTT JN')
# (504, 'PNBE-BTI FTR', 'PATNA JN.', 'BATHINDA JN')
# (506, 'PNBE-PTA FTR', 'PATNA JN.', 'PATIALA')
# (557, 'RSD-PJP BSF', 'URKURA', 'PANJIPARA')
# (22439, 'SVDK VANDEBHARAT', 'NEW DELHI', 'SHMATA VD KATRA')
# (604, 'PNBE-ASR FTR', 'PATNA JN.', 'AMRITSAR JN.')
# (1011, 'CSMT-NGP SF', 'CST-MUMBAI', 'NAGPUR JN.(CR)')
# (1037, 'LTT-SWV SPL', 'LOKMANYA TILAK TERMINUS', 'SAWANTWADI ROAD')
# ...

# %%
import random 

def generate_pnr():
    region_code = random.choice(['1', '2', '3', '4', '5', '6', '7', '8', '9'])  # First digit
    remaining_digits = ''.join([str(random.randint(0, 9)) for _ in range(9)])  # Remaining 9 digits
    pnr_number = region_code + remaining_digits
    return pnr_number

print(generate_pnr())
# Out:
# 1791496353
